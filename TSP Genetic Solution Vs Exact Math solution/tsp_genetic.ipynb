# %%
import numpy as np, random, operator
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dist_matrix0.csv', index_col=0)

# %%
df
num_cities = len(df)

# %%
def fitness(chromosome,df):
    fitness = 0
    for i in range(len(chromosome)):
        fitness += df.iloc[chromosome[i-1],chromosome[i]]
    return -fitness

# %%
class Agent():
    def __init__(self, num_cities):
        self.create_route()
        self.fitness = fitness(self.route,df)
    
    def create_route(self):
        self.route = list(random.sample(range(len(df)), len(df)))
    def mutate(self):
        for swaping in range(len(self.route)):
            if(random.random() < 0.005):
                swap_with = int(random.random() * len(self.route))
                city1 = self.route[swaping]
                city2 = self.route[swap_with]
                self.route[swaping] = city2
                self.route[swap_with] = city1
        self.fitness = fitness(self.route,df)

# %%
#Se toma la mitad de la población con mejor fitness
def selection(population):
    #Proceso de seleccion generico, no creo que sea el más adecuado
    sorted_population = sorted(population, key=lambda x: x.fitness, reverse=True)
    return sorted_population[:len(population)//2]
    
#Se realiza el cruce de los cromosomas de los agentes
def crossover(population):
    #Función usada en PROBLEMA ANTERIOR, son parece que sea la mejor manera de hacer crossover
    offspring = []
    
    # Convert the elements list to a numpy array
    arpopulation = np.array(population)
    
    # Shuffle the elements using numpy's shuffle
    np.random.shuffle(arpopulation)

    # Check if the number of elements is even
    if len(arpopulation) % 2 != 0:
        raise ValueError("The number of elements must be even to form pairs.")
    
    # Reshape the array into pairs
    arparents = arpopulation.reshape(-1, 2)
    
    # Convert the numpy array of pairs back to a list of lists
    parents = arparents.tolist()
    
    for parent in parents:
        parent1 = parent[0] 
        parent2 = parent[1]
        child1 = Agent(num_cities)
        child2 = Agent(num_cities)
        geneA = int(random.random() * len(parent1.route))
        geneB = int(random.random() * len(parent1.route))
        startGene = min(geneA, geneB)
        endGene = max(geneA, geneB)
        for i in range(startGene, endGene):
            child1.route[i] = parent1.route[i]
            child2.route[i] = parent2.route[i]
        for i in range(len(parent2.route)):
            if parent2.route[i] not in child1.route:
                for j in range(len(parent2.route)):
                    if child1.route[j] == -1:
                        child1.route[j] = parent2.route[i]
                        break
            if parent1.route[i] not in child2.route:
                for j in range(len(parent1.route)):
                    if child2.route[j] == -1:
                        child2.route[j] = parent1.route[i]
                        break
        childs = [child1, child2]
        mutated_childs = mutation(childs)
        # Check the fitness of the mutated children
        for child in mutated_childs:
            child.fitness = fitness(child.route,df)
        mutated_childs = sorted(mutated_childs, key=lambda x: x.fitness)
        mutated_childs = mutated_childs
        offspring.extend(mutated_childs)
    print(len(offspring))

        
        
    return offspring
# Se realiza la probabilidad de mutación
def mutation(population):
    for entity in population:
        if random.random() < 0.01: #Probabilidad de mutacion
            entity.mutate()
    return population

# %%
#population_size = int(0.01 * len(weight)**20)
from numpy import cross

# Se inicializa la población
population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever1 = best_agent
    else:
        if best_agent.fitness > best_agent_ever1.fitness:
            best_agent_ever1 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -357.08000000000004
# 1000
# Epoca:2
# Este es el fitness mejor agente: -344.92
# 1000
# Epoca:3
# Este es el fitness mejor agente: -323.28000000000014
# 1000
# Epoca:4
# Este es el fitness mejor agente: -323.28000000000014
# 1000
# Epoca:5
# Este es el fitness mejor agente: -323.28000000000014
# 1000
# Epoca:6
# Este es el fitness mejor agente: -323.28000000000014
# 1000
# Epoca:7
# Este es el fitness mejor agente: -316.46
# 1000
# Epoca:8
# Este es el fitness mejor agente: -316.46
# 1000
# Epoca:9
# Este es el fitness mejor agente: -307.07000000000005
# 1000
# Epoca:10
# Este es el fitness mejor agente: -299.0299999999999
# 1000
# Epoca:11
# Este es el fitness mejor agente: -299.0299999999999
# 1000
# Epoca:12
# Este es el fitness mejor agente: -299.0299999999999
# 1000
# Epoca:13
# Este es el fitness mejor agente: -298.7699999999999
# 1000
# Epoca:14
# Este es el fitness mejor agente: -298.7699999999999
# 1000
# Epoca:15
# ...

# %%
df = pd.read_csv('dist_matrix1.csv', index_col=0)

# %%
# Se inicializa la población
population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever2 = best_agent
    else:
        if best_agent.fitness > best_agent_ever2.fitness:
            best_agent_ever2 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -323.4100000000001
# 1000
# Epoca:2
# Este es el fitness mejor agente: -292.45000000000005
# 1000
# Epoca:3
# Este es el fitness mejor agente: -292.45000000000005
# 1000
# Epoca:4
# Este es el fitness mejor agente: -292.45000000000005
# 1000
# Epoca:5
# Este es el fitness mejor agente: -292.45000000000005
# 1000
# Epoca:6
# Este es el fitness mejor agente: -292.45000000000005
# 1000
# Epoca:7
# Este es el fitness mejor agente: -292.45000000000005
# 1000
# Epoca:8
# Este es el fitness mejor agente: -292.45000000000005
# 1000
# Epoca:9
# Este es el fitness mejor agente: -282.93
# 1000
# Epoca:10
# Este es el fitness mejor agente: -282.01000000000005
# 1000
# Epoca:11
# Este es el fitness mejor agente: -282.01000000000005
# 1000
# Epoca:12
# Este es el fitness mejor agente: -266.51000000000005
# 1000
# Epoca:13
# Este es el fitness mejor agente: -253.07
# 1000
# Epoca:14
# Este es el fitness mejor agente: -253.07
# 1000
# Epoca:15
# ...

# %%
df = pd.read_csv('dist_matrix2.csv', index_col=0)

population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever3 = best_agent
    else:
        if best_agent.fitness > best_agent_ever3.fitness:
            best_agent_ever3 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -326.6300000000001
# 1000
# Epoca:2
# Este es el fitness mejor agente: -304.53
# 1000
# Epoca:3
# Este es el fitness mejor agente: -297.40999999999997
# 1000
# Epoca:4
# Este es el fitness mejor agente: -286.31999999999994
# 1000
# Epoca:5
# Este es el fitness mejor agente: -286.31999999999994
# 1000
# Epoca:6
# Este es el fitness mejor agente: -286.31999999999994
# 1000
# Epoca:7
# Este es el fitness mejor agente: -279.16999999999996
# 1000
# Epoca:8
# Este es el fitness mejor agente: -279.16999999999996
# 1000
# Epoca:9
# Este es el fitness mejor agente: -279.16999999999996
# 1000
# Epoca:10
# Este es el fitness mejor agente: -279.16999999999996
# 1000
# Epoca:11
# Este es el fitness mejor agente: -279.16999999999996
# 1000
# Epoca:12
# Este es el fitness mejor agente: -261.93999999999994
# 1000
# Epoca:13
# Este es el fitness mejor agente: -261.93999999999994
# 1000
# Epoca:14
# Este es el fitness mejor agente: -261.93999999999994
# ...

# %%
df = pd.read_csv('dist_matrix3.csv', index_col=0)

population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever4 = best_agent
    else:
        if best_agent.fitness > best_agent_ever4.fitness:
            best_agent_ever4 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -367.44000000000017
# 1000
# Epoca:2
# Este es el fitness mejor agente: -333.88
# 1000
# Epoca:3
# Este es el fitness mejor agente: -333.88
# 1000
# Epoca:4
# Este es el fitness mejor agente: -333.88
# 1000
# Epoca:5
# Este es el fitness mejor agente: -322.71000000000004
# 1000
# Epoca:6
# Este es el fitness mejor agente: -322.71000000000004
# 1000
# Epoca:7
# Este es el fitness mejor agente: -319.38000000000005
# 1000
# Epoca:8
# Este es el fitness mejor agente: -319.38000000000005
# 1000
# Epoca:9
# Este es el fitness mejor agente: -319.38000000000005
# 1000
# Epoca:10
# Este es el fitness mejor agente: -319.38000000000005
# 1000
# Epoca:11
# Este es el fitness mejor agente: -319.38000000000005
# 1000
# Epoca:12
# Este es el fitness mejor agente: -319.38000000000005
# 1000
# Epoca:13
# Este es el fitness mejor agente: -300.88
# 1000
# Epoca:14
# Este es el fitness mejor agente: -300.88
# 1000
# Epoca:15
# ...

# %%
df = pd.read_csv('dist_matrix4.csv', index_col=0)
population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever5 = best_agent
    else:
        if best_agent.fitness > best_agent_ever5.fitness:
            best_agent_ever5 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -344.68000000000006
# 1000
# Epoca:2
# Este es el fitness mejor agente: -329.67999999999995
# 1000
# Epoca:3
# Este es el fitness mejor agente: -329.67999999999995
# 1000
# Epoca:4
# Este es el fitness mejor agente: -329.67999999999995
# 1000
# Epoca:5
# Este es el fitness mejor agente: -329.67999999999995
# 1000
# Epoca:6
# Este es el fitness mejor agente: -329.67999999999995
# 1000
# Epoca:7
# Este es el fitness mejor agente: -329.67999999999995
# 1000
# Epoca:8
# Este es el fitness mejor agente: -312.1599999999999
# 1000
# Epoca:9
# Este es el fitness mejor agente: -293.73
# 1000
# Epoca:10
# Este es el fitness mejor agente: -293.73
# 1000
# Epoca:11
# Este es el fitness mejor agente: -293.73
# 1000
# Epoca:12
# Este es el fitness mejor agente: -293.73
# 1000
# Epoca:13
# Este es el fitness mejor agente: -288.15
# 1000
# Epoca:14
# Este es el fitness mejor agente: -288.15
# 1000
# Epoca:15
# ...

# %%
df = pd.read_csv('dist_matrix5.csv', index_col=0)
population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever6 = best_agent
    else:
        if best_agent.fitness > best_agent_ever6.fitness:
            best_agent_ever6 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -301.41999999999996
# 1000
# Epoca:2
# Este es el fitness mejor agente: -298.0
# 1000
# Epoca:3
# Este es el fitness mejor agente: -298.0
# 1000
# Epoca:4
# Este es el fitness mejor agente: -292.65999999999997
# 1000
# Epoca:5
# Este es el fitness mejor agente: -292.65999999999997
# 1000
# Epoca:6
# Este es el fitness mejor agente: -292.65999999999997
# 1000
# Epoca:7
# Este es el fitness mejor agente: -288.11999999999995
# 1000
# Epoca:8
# Este es el fitness mejor agente: -288.11999999999995
# 1000
# Epoca:9
# Este es el fitness mejor agente: -288.11999999999995
# 1000
# Epoca:10
# Este es el fitness mejor agente: -285.32000000000005
# 1000
# Epoca:11
# Este es el fitness mejor agente: -285.32000000000005
# 1000
# Epoca:12
# Este es el fitness mejor agente: -285.32000000000005
# 1000
# Epoca:13
# Este es el fitness mejor agente: -285.32000000000005
# 1000
# Epoca:14
# Este es el fitness mejor agente: -280.23999999999995
# 1000
# ...

# %%
df = pd.read_csv('dist_matrix6.csv', index_col=0)
population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever7 = best_agent
    else:
        if best_agent.fitness > best_agent_ever7.fitness:
            best_agent_ever7 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -305.61
# 1000
# Epoca:2
# Este es el fitness mejor agente: -289.5
# 1000
# Epoca:3
# Este es el fitness mejor agente: -289.5
# 1000
# Epoca:4
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:5
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:6
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:7
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:8
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:9
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:10
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:11
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:12
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:13
# Este es el fitness mejor agente: -286.20000000000005
# 1000
# Epoca:14
# Este es el fitness mejor agente: -278.17999999999995
# 1000
# Epoca:15
# ...

# %%
df = pd.read_csv('dist_matrix7.csv', index_col=0)
population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever8 = best_agent
    else:
        if best_agent.fitness > best_agent_ever8.fitness:
            best_agent_ever8 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -309.74
# 1000
# Epoca:2
# Este es el fitness mejor agente: -309.74
# 1000
# Epoca:3
# Este es el fitness mejor agente: -309.74
# 1000
# Epoca:4
# Este es el fitness mejor agente: -288.6500000000001
# 1000
# Epoca:5
# Este es el fitness mejor agente: -288.6500000000001
# 1000
# Epoca:6
# Este es el fitness mejor agente: -288.6500000000001
# 1000
# Epoca:7
# Este es el fitness mejor agente: -288.6500000000001
# 1000
# Epoca:8
# Este es el fitness mejor agente: -288.6500000000001
# 1000
# Epoca:9
# Este es el fitness mejor agente: -288.6500000000001
# 1000
# Epoca:10
# Este es el fitness mejor agente: -288.6500000000001
# 1000
# Epoca:11
# Este es el fitness mejor agente: -288.6500000000001
# 1000
# Epoca:12
# Este es el fitness mejor agente: -283.07000000000005
# 1000
# Epoca:13
# Este es el fitness mejor agente: -283.07000000000005
# 1000
# Epoca:14
# Este es el fitness mejor agente: -283.07000000000005
# 1000
# Epoca:15
# ...

# %%
df = pd.read_csv('dist_matrix8.csv', index_col=0)
population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever9 = best_agent
    else:
        if best_agent.fitness > best_agent_ever9.fitness:
            best_agent_ever9 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -327.8
# 1000
# Epoca:2
# Este es el fitness mejor agente: -327.8
# 1000
# Epoca:3
# Este es el fitness mejor agente: -318.25
# 1000
# Epoca:4
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:5
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:6
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:7
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:8
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:9
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:10
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:11
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:12
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:13
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:14
# Este es el fitness mejor agente: -255.35999999999996
# 1000
# Epoca:15
# ...

# %%
df = pd.read_csv('dist_matrix9.csv', index_col=0)
population_size = 1000
population = [Agent(num_cities) for i in range(population_size)]
counter = 0
past_agent = 0
epoch = 0
#Número de epocas

while epoch < 1000:
    epoch += 1
    babies = crossover(population)
    population.extend(babies)
    population = selection(population)
    #Look for the best agent
    best_agent = max(population, key=lambda x: x.fitness)
    if best_agent.fitness == past_agent:
        counter += 1
    else:
        counter = 0
    past_agent = best_agent.fitness
    print("Epoca:"+ str(epoch))
    print("Este es el fitness mejor agente: " + str(best_agent.fitness))
    #Save the best agent of all time
    if epoch == 1:
        best_agent_ever10 = best_agent
    else:
        if best_agent.fitness > best_agent_ever10.fitness:
            best_agent_ever10 = best_agent
# Out:
# 1000
# Epoca:1
# Este es el fitness mejor agente: -318.36000000000007
# 1000
# Epoca:2
# Este es el fitness mejor agente: -314.06
# 1000
# Epoca:3
# Este es el fitness mejor agente: -299.68999999999994
# 1000
# Epoca:4
# Este es el fitness mejor agente: -299.68999999999994
# 1000
# Epoca:5
# Este es el fitness mejor agente: -275.4
# 1000
# Epoca:6
# Este es el fitness mejor agente: -275.4
# 1000
# Epoca:7
# Este es el fitness mejor agente: -275.4
# 1000
# Epoca:8
# Este es el fitness mejor agente: -275.4
# 1000
# Epoca:9
# Este es el fitness mejor agente: -275.4
# 1000
# Epoca:10
# Este es el fitness mejor agente: -275.4
# 1000
# Epoca:11
# Este es el fitness mejor agente: -275.4
# 1000
# Epoca:12
# Este es el fitness mejor agente: -275.4
# 1000
# Epoca:13
# Este es el fitness mejor agente: -275.4
# 1000
# Epoca:14
# Este es el fitness mejor agente: -269.56000000000006
# 1000
# Epoca:15
# Este es el fitness mejor agente: -269.56000000000006
# 1000
# Epoca:16
# ...

# %%
print("El mejor agente de la primera matriz es: " + str(best_agent_ever1.fitness))
print("El mejor agente de la segunda matriz es: " + str(best_agent_ever2.fitness))
print("El mejor agente de la tercera matriz es: " + str(best_agent_ever3.fitness))
print("El mejor agente de la cuarta matriz es: " + str(best_agent_ever4.fitness))
print("El mejor agente de la quinta matriz es: " + str(best_agent_ever5.fitness))
print("El mejor agente de la sexta matriz es: " + str(best_agent_ever6.fitness))
print("El mejor agente de la septima matriz es: " + str(best_agent_ever7.fitness))
print("El mejor agente de la octava matriz es: " + str(best_agent_ever8.fitness))
print("El mejor agente de la novena matriz es: " + str(best_agent_ever9.fitness))
print("El mejor agente de la decima matriz es: " + str(best_agent_ever10.fitness))
# Out:
# El mejor agente de la primera matriz es: -170.54
# El mejor agente de la segunda matriz es: -135.35999999999999
# El mejor agente de la tercera matriz es: -127.37999999999997
# El mejor agente de la cuarta matriz es: -178.95
# El mejor agente de la quinta matriz es: -182.56000000000003
# El mejor agente de la sexta matriz es: -142.31
# El mejor agente de la septima matriz es: -135.37
# El mejor agente de la octava matriz es: -160.07999999999998
# El mejor agente de la novena matriz es: -117.68
# El mejor agente de la decima matriz es: -141.03000000000003
